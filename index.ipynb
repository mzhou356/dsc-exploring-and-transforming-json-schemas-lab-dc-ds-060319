# %% [markdown]
# # Exploring and Transforming JSON Schemas

# %% [markdown]
# # Introduction
#
# In this lesson, you'll formalize how to explore a JSON file whose structure and schema is unknown to you. This often happens in practice when you are handed a file or stumble upon one with little documentation.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Explore unknown JSON schemas
# * Access and manipulate data inside a JSON file
# * Convert JSON to alternative data formats

# %% [markdown]
# ## Loading the JSON file
#
# Load the data from the file disease_data.json.

# %%
#Your code here 
import json
f = open('disease_data.json')
data = json.load(f)

# %% [markdown]
# ## Explore the first and second levels of the schema hierarchy

# %%
#Your code here
data.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
type(data['meta']), type(data['data'])
# Out:
# (dict, list)

# %%
data['meta'].keys()
# Out:
# dict_keys(['view'])

# %%
data['data'][:1]
# Out:
# [[1,
#   'FF49C41F-CE8D-46C4-9164-653B1227CF6F',
#   1,
#   1527194521,
#   '959778',
#   1527194521,
#   '959778',
#   None,
#   '2016',
#   '2016',
#   'US',
#   'United States',
#   'BRFSS',
#   'Alcohol',
#   'Binge drinking prevalence among adults aged >= 18 years',
#   None,
#   '%',
#   'Crude Prevalence',
#   '16.9',
#   '16.9',
#   '*',
#   '50 States + DC: US Median',
#   '16',
#   '18',
#   'Overall',
#   'Overall',
#   None,
#   None,
#   None,
#   None,
#   [None, None, None, None, None],
#   None,
#   '59',
#   'ALC',
#   'ALC2_2',
#   'CRDPREV',
#   'OVERALL',
#   'OVR',
#   None,
#   None,
#   None,
#   None]]

# %% [markdown]
# ## Convert to a DataFrame
#
# Create a DataFrame from the JSON file. Be sure to retrive the column names for the dataframe. (Search within the 'meta' key of the master dictionary.) The DataFrame should include all 42 columns.

# %%
import pandas as pd

# %%
columns = [col['name'] for col in data['meta']['view']['columns']]

# %%
columns
# Out:
# ['sid',
#  'id',
#  'position',
#  'created_at',
#  'created_meta',
#  'updated_at',
#  'updated_meta',
#  'meta',
#  'YearStart',
#  'YearEnd',
#  'LocationAbbr',
#  'LocationDesc',
#  'DataSource',
#  'Topic',
#  'Question',
#  'Response',
#  'DataValueUnit',
#  'DataValueType',
#  'DataValue',
#  'DataValueAlt',
#  'DataValueFootnoteSymbol',
#  'DatavalueFootnote',
#  'LowConfidenceLimit',
#  'HighConfidenceLimit',
#  'StratificationCategory1',
#  'Stratification1',
#  'StratificationCategory2',
#  'Stratification2',
#  'StratificationCategory3',
#  'Stratification3',
#  'GeoLocation',
#  'ResponseID',
#  'LocationID',
#  'TopicID',
#  'QuestionID',
#  'DataValueTypeID',
#  'StratificationCategoryID1',
#  'StratificationID1',
#  'StratificationCategoryID2',
#  'StratificationID2',
#  'StratificationCategoryID3',
#  'StratificationID3']

# %%
#Your code here
df = pd.DataFrame(data['data'],columns=columns)
df.head()
# Out:
#    sid                                    id  position  created_at  \
# 0    1  FF49C41F-CE8D-46C4-9164-653B1227CF6F         1  1527194521
# 1    2  F4468C3D-340A-4CD2-84A3-DF554DFF065E         2  1527194521
# 2    3  65609156-A343-4869-B03F-2BA62E96AC19         3  1527194521
# 3    4  0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3         4  1527194521
# 4    5  D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B         5  1527194521
#
#   created_meta  updated_at updated_meta  meta YearStart YearEnd  \
# 0       959778  1527194521       959778  None      2016    2016
# 1       959778  1527194521       959778  None      2016    2016
# 2       959778  1527194521       959778  None      2016    2016
# 3       959778  1527194521       959778  None      2016    2016
# 4       959778  1527194521       959778  None      2016    2016
#
#          ...        LocationID TopicID QuestionID DataValueTypeID  \
# 0        ...                59     ALC     ALC2_2         CRDPREV
# 1        ...                01     ALC     ALC2_2         CRDPREV
# 2        ...                02     ALC     ALC2_2         CRDPREV
# 3        ...                04     ALC     ALC2_2         CRDPREV
# 4        ...                05     ALC     ALC2_2         CRDPREV
#
#   StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 0                   OVERALL               OVR                      None
# 1                   OVERALL               OVR                      None
# 2                   OVERALL               OVR                      None
# 3                   OVERALL               OVR                      None
# 4                   OVERALL               OVR                      None
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0              None                      None              None
# 1              None                      None              None
# 2              None                      None              None
# 3              None                      None              None
# 4              None                      None              None
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Level-Up
# ## Create a bar graph of states with the highest asthma rates for adults age 18+

#
# 9218        959778  1527194523       959778  None      2016    2016
# 9370        959778  1527194523       959778  None      2016    2016
# 9371        959778  1527194523       959778  None      2016    2016
# 9372        959778  1527194523       959778  None      2016    2016
# 9373        959778  1527194523       959778  None      2016    2016
# 9374        959778  1527194523       959778  None      2016    2016
# 9375        959778  1527194523       959778  None      2016    2016
# 9376        959778  1527194523       959778  None      2016    2016
# 9377        959778  1527194523       959778  None      2016    2016
# 9378        959778  1527194523       959778  None      2016    2016
# 9379        959778  1527194523       959778  None      2016    2016
# 9380        959778  1527194523       959778  None      2016    2016
# 9381        959778  1527194523       959778  None      2016    2016
# 9382        959778  1527194523       959778  None      2016    2016
# 9383        959778  1527194523       959778  None      2016    2016
# 9384        959778  1527194523       959778  None      2016    2016
# 9385        959778  1527194523       959778  None      2016    2016
# ...            ...         ...          ...   ...       ...     ...
# 10199       959778  1527194523       959778  None      2016    2016
# 10200       959778  1527194523       959778  None      2016    2016
# 10201       959778  1527194523       959778  None      2016    2016
# 10202       959778  1527194523       959778  None      2016    2016
# 10203       959778  1527194523       959778  None      2016    2016
# 10204       959778  1527194523       959778  None      2016    2016
# 10205       959778  1527194523       959778  None      2016    2016
# 10206       959778  1527194523       959778  None      2016    2016
# 10207       959778  1527194523       959778  None      2016    2016
# 10208       959778  1527194523       959778  None      2016    2016
# 10209       959778  1527194523       959778  None      2016    2016
# 10210       959778  1527194523       959778  None      2016    2016
# 10211       959778  1527194523       959778  None      2016    2016
# 10212       959778  1527194523       959778  None      2016    2016
# 10213       959778  1527194523       959778  None      2016    2016
# 10214       959778  1527194523       959778  None      2016    2016
# 10215       959778  1527194523       959778  None      2016    2016
# 10216       959778  1527194523       959778  None      2016    2016
# 10217       959778  1527194523       959778  None      2016    2016
# 10218       959778  1527194523       959778  None      2016    2016
# 10219       959778  1527194523       959778  None      2016    2016
# 10220       959778  1527194523       959778  None      2016    2016
# 10221       959778  1527194523       959778  None      2016    2016
# 10222       959778  1527194523       959778  None      2016    2016
# 10223       959778  1527194523       959778  None      2016    2016
# 10225       959778  1527194523       959778  None      2016    2016
# 10226       959778  1527194523       959778  None      2016    2016
# 10227       959778  1527194523       959778  None      2016    2016
# 10228       959778  1527194523       959778  None      2016    2016
# 10229       959778  1527194523       959778  None      2016    2016
#
#              ...        LocationID TopicID QuestionID DataValueTypeID  \
# 4725         ...                17     AST     AST1_1         CRDPREV
# 5529         ...                18     AST     AST1_1         CRDPREV
# 5632         ...                19     AST     AST1_1         CRDPREV
# 6777         ...                20     AST     AST1_1         CRDPREV
# 7034         ...                21     AST     AST1_1         CRDPREV
# 7337         ...                22     AST     AST1_1         CRDPREV
# 7428         ...                23     AST     AST1_1         CRDPREV
# 7499         ...                24     AST     AST1_1         CRDPREV
# 7966         ...                50     AST     AST1_1         CRDPREV
# 8114         ...                51     AST     AST1_1         CRDPREV
# 8135         ...                12     AST     AST1_1         CRDPREV
# 8234         ...                66     AST     AST1_1      AGEADJPREV
# 9138         ...                15     AST     AST1_1         CRDPREV
# 9218         ...                16     AST     AST1_1         CRDPREV
# 9370         ...                59     AST     AST1_1         CRDPREV
# 9371         ...                01     AST     AST1_1         CRDPREV
# 9372         ...                02     AST     AST1_1         CRDPREV
# 9373         ...                04     AST     AST1_1         CRDPREV
# 9374         ...                05     AST     AST1_1         CRDPREV
# 9375         ...                06     AST     AST1_1         CRDPREV
# 9376         ...                08     AST     AST1_1         CRDPREV
# 9377         ...                09     AST     AST1_1         CRDPREV
# 9378         ...                10     AST     AST1_1         CRDPREV
# 9379         ...                11     AST     AST1_1         CRDPREV
# 9380         ...                12     AST     AST1_1         CRDPREV
# 9381         ...                13     AST     AST1_1         CRDPREV
# 9382         ...                15     AST     AST1_1         CRDPREV
# 9383         ...                16     AST     AST1_1         CRDPREV
# 9384         ...                17     AST     AST1_1         CRDPREV
# 9385         ...                18     AST     AST1_1         CRDPREV
# ...          ...               ...     ...        ...             ...
# 10199        ...                28     AST     AST1_1      AGEADJPREV
# 10200        ...                29     AST     AST1_1      AGEADJPREV
# 10201        ...                30     AST     AST1_1      AGEADJPREV
# 10202        ...                31     AST     AST1_1      AGEADJPREV
# 10203        ...                32     AST     AST1_1      AGEADJPREV
# 10204        ...                33     AST     AST1_1      AGEADJPREV
# 10205        ...                34     AST     AST1_1      AGEADJPREV
# 10206        ...                35     AST     AST1_1      AGEADJPREV
# 10207        ...                36     AST     AST1_1      AGEADJPREV
# 10208        ...                37     AST     AST1_1      AGEADJPREV
# 10209        ...                38     AST     AST1_1      AGEADJPREV
# 10210        ...                39     AST     AST1_1      AGEADJPREV
# 10211        ...                40     AST     AST1_1      AGEADJPREV
# 10212        ...                41     AST     AST1_1      AGEADJPREV
# 10213        ...                42     AST     AST1_1      AGEADJPREV
# 10214        ...                44     AST     AST1_1      AGEADJPREV
# 10215        ...                45     AST     AST1_1      AGEADJPREV
# 10216        ...                46     AST     AST1_1      AGEADJPREV
# 10217        ...                47     AST     AST1_1      AGEADJPREV
# 10218        ...                48     AST     AST1_1      AGEADJPREV
# 10219        ...                49     AST     AST1_1      AGEADJPREV
# 10220        ...                50     AST     AST1_1      AGEADJPREV
# 10221        ...                51     AST     AST1_1      AGEADJPREV
# 10222        ...                53     AST     AST1_1      AGEADJPREV
# 10223        ...                54     AST     AST1_1      AGEADJPREV
# 10225        ...                55     AST     AST1_1      AGEADJPREV
# 10226        ...                56     AST     AST1_1      AGEADJPREV
# 10227        ...                66     AST     AST1_1      AGEADJPREV
# 10228        ...                72     AST     AST1_1      AGEADJPREV
# 10229        ...                78     AST     AST1_1      AGEADJPREV
#
#       StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 4725                     GENDER              GENM                      None
# 5529                     GENDER              GENM                      None
# 5632                     GENDER              GENM                      None
# 6777                     GENDER              GENM                      None
# 7034                     GENDER              GENM                      None
# 7337                     GENDER              GENM                      None
# 7428                     GENDER              GENM                      None
# 7499                     GENDER              GENM                      None
# 7966                     GENDER              GENM                      None
# 8114                     GENDER              GENM                      None
# 8135                     GENDER              GENF                      None
# 8234                     GENDER              GENF                      None
# 9138                     GENDER              GENM                      None
# 9218                     GENDER              GENM                      None
# 9370                    OVERALL               OVR                      None
# 9371                    OVERALL               OVR                      None
